# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# This code creates a virtual display to draw game images on. 
# If you are running locally, just ignore it
import os
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1
# Out:
# Starting virtual X frame buffer: Xvfb.
# env: DISPLAY=:1

# %% [markdown]
# ### OpenAI Gym
#
# We're gonna spend several next weeks learning algorithms that solve decision processes. We are then in need of some interesting decision problems to test our algorithms.
#
# That's where OpenAI gym comes into play. It's a python library that wraps many classical decision problems including robot control, videogames and board games.
#
# So here's how it works:

# %%
import gym
env = gym.make("MountainCar-v0")

plt.imshow(env.render('rgb_array'))
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Observation space: Box(2,)
# Action space: Discrete(3)

# %% [markdown]
# Note: if you're running this on your local machine, you'll see a window pop up with the image above. Don't close it, just alt-tab away.

# %% [markdown]
# ### Gym interface
#
# The three main methods of an environment are
# * __reset()__ - reset environment to initial state, _return first observation_
# * __render()__ - show current environment state (a more colorful version :) )
# * __step(a)__ - commit action __a__ and return (new observation, reward, is done, info)
#  * _new observation_ - an observation right after commiting the action __a__
#  * _reward_ - a number representing your reward for commiting action __a__
#  * _is done_ - True if the MDP has just finished, False if still in progress
#  * _info_ - some auxilary stuff about what just happened. Ignore it ~~for now~~.

# %%
obs0 = env.reset()
print("initial observation code:", obs0)

# Note: in MountainCar, observation is just two numbers: car position and velocity
# Out:
# initial observation code: [-0.52852526  0.        ]

# %%
print("taking action 2 (right)")
new_obs, reward, is_done, _ = env.step(2)

print("new observation code:", new_obs)
print("reward:", reward)
print("is game over?:", is_done)

# Note: as you can see, the car has moved to the riht slightly (around 0.0005)
# Out:
# taking action 2 (right)
# new observation code: [-0.52748832  0.00103695]
# reward: -1.0
# is game over?: False

# %% [markdown]
# ### Play with it
#
# Below is the code that drives the car to the right.
#
# However, it doesn't reach the flag at the far right due to gravity.
#
# __Your task__ is to fix it. Find a strategy that reaches the flag.
#
# You're not required to build any sophisticated algorithms for now, feel free to hard-code :)
#
# _Hint: your action at each step should depend either on __t__ or on __s__._

# %%
# create env manually to set time limit. Please don't change this.
TIME_LIMIT = 250
env = gym.wrappers.TimeLimit(gym.envs.classic_control.MountainCarEnv(),
                             max_episode_steps=TIME_LIMIT + 1)
s = env.reset()
actions = {'left': 0, 'stop': 1, 'right': 2}

# prepare "display"
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

def policy(t):
    # YOUR CODE HERE
    
    if(t%100<20):
        return actions['left']
    if(t%100==20):
        return actions['stop']
    
    return actions['right']


for t in range(TIME_LIMIT):
    
    s, r, done, _ = env.step(policy(t))
    
    #draw game image on display
    ax.clear()
    ax.imshow(env.render('rgb_array'))
    fig.canvas.draw()
    
    if done:
        print("Well done!")
        break
else:    
    print("Time limit exceeded. Try again.")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-58eb98b257d4> in <module>()
#      29
#      30     #draw game image on display
# ---> 31     ax.clear()
#      32     ax.imshow(env.render('rgb_array'))
#      33     fig.canvas.draw()
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py in clear(self)
#    1106     def clear(self):
#    1107         """Clear the axes."""
# -> 1108         self.cla()
#    1109
#    1110     def get_facecolor(self):
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py in cla(self)
#     968
#     969         for name, spine in self.spines.items():
# --> 970             spine.cla()
#     971
#     972         self.ignore_existing_data_limits = True
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/spines.py in cla(self)
#     178         self._position = None  # clear position
#     179         if self.axis is not None:
# --> 180             self.axis.cla()
#     181
#     182     def is_frame_like(self):
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axis.py in cla(self)
#     800         self.label.set_text('')  # self.set_label_text would change isDefault_
#     801
# --> 802         self._set_scale('linear')
#     803
#     804         # Clear the callback registry for this axis, or it may "leak"
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     766     def _set_scale(self, value, **kwargs):
#     767         self._scale = mscale.scale_factory(value, self, **kwargs)
# --> 768         self._scale.set_default_locators_and_formatters(self)
#     769
#     770         self.isDefault_majloc = True
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/scale.py in set_default_locators_and_formatters(self, axis)
#      66         linear scaling.
#      67         """
# ---> 68         axis.set_major_locator(AutoLocator())
#      69         axis.set_major_formatter(ScalarFormatter())
#      70         axis.set_minor_formatter(NullFormatter())
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/ticker.py in __init__(self)
#    2536             nbins = 'auto'
#    2537             steps = [1, 2, 2.5, 5, 10]
# -> 2538         MaxNLocator.__init__(self, nbins=nbins, steps=steps)
#    2539
#    2540
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/ticker.py in __init__(self, *args, **kwargs)
#    1865                 raise ValueError(
#    1866                     "Keywords are required for all arguments except 'nbins'")
# -> 1867         self.set_params(**self.default_params)
#    1868         self.set_params(**kwargs)
#    1869
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/ticker.py in set_params(self, **kwargs)
#    1917             else:
#    1918                 self._steps = self._validate_steps(steps)
# -> 1919             self._extended_steps = self._staircase(self._steps)
#    1920         if 'integer' in kwargs:
#    1921             self._integer = kwargs['integer']
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/ticker.py in _staircase(steps)
#    1893         # than necessary.
#    1894         flights = (0.1 * steps[:-1], steps, 10 * steps[1])
# -> 1895         return np.hstack(flights)
#    1896
#    1897     def set_params(self, **kwargs):
#
# /opt/conda/lib/python3.6/site-packages/numpy/core/shape_base.py in hstack(tup)
#     284     # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     285     if arrs and arrs[0].ndim == 1:
# --> 286         return _nx.concatenate(arrs, 0)
#     287     else:
#     288         return _nx.concatenate(arrs, 1)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Submit to coursera

# %%
from submit import submit_interface
submit_interface(policy, "myblueiceeyes@hotmail.com", "IpXQWR65RNV7bRUE")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Submitted to Coursera platform. See results on assignment page!
