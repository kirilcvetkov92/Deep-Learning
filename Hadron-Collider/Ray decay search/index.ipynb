# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas
from sklearn.model_selection import train_test_split

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import roc_curve, roc_auc_score

from hep_ml import metrics

# %% [markdown]
# # Load dataset and split into training / test
#
# `training.csv` is a mixture of simulated signal, real background.
# It has the following columns.
#
# `test.csv` has the following columns:

# %%
train_ada = pandas.read_csv('reference/training.csv', sep=',')
test_ada = pandas.read_csv('reference/test.csv', sep=',', index_col='id')

# %%
print ("Training full sample columns:", ", ".join(train_ada.columns), "\nShape:", train_ada.shape)
# Out:
# Training full sample columns: id, LifeTime, dira, FlightDistance, FlightDistanceError, IP, IPSig, VertexChi2, pt, DOCAone, DOCAtwo, DOCAthree, IP_p0p2, IP_p1p2, isolationa, isolationb, isolationc, isolationd, isolatione, isolationf, iso, CDF1, CDF2, CDF3, ISO_SumBDT, p0_IsoBDT, p1_IsoBDT, p2_IsoBDT, p0_track_Chi2Dof, p1_track_Chi2Dof, p2_track_Chi2Dof, p0_IP, p1_IP, p2_IP, p0_IPSig, p1_IPSig, p2_IPSig, p0_pt, p1_pt, p2_pt, p0_p, p1_p, p2_p, p0_eta, p1_eta, p2_eta, SPDhits, production, signal, mass, min_ANNmuon
# Shape: (67553, 51)

# %%
print ("Test full sample columns:", ", ".join(test_ada.columns), "\nShape:", test_ada.shape)
test_ada.head()
# Out:
# Test full sample columns: LifeTime, dira, FlightDistance, FlightDistanceError, IP, IPSig, VertexChi2, pt, DOCAone, DOCAtwo, DOCAthree, IP_p0p2, IP_p1p2, isolationa, isolationb, isolationc, isolationd, isolatione, isolationf, iso, CDF1, CDF2, CDF3, ISO_SumBDT, p0_IsoBDT, p1_IsoBDT, p2_IsoBDT, p0_track_Chi2Dof, p1_track_Chi2Dof, p2_track_Chi2Dof, p0_IP, p1_IP, p2_IP, p0_IPSig, p1_IPSig, p2_IPSig, p0_pt, p1_pt, p2_pt, p0_p, p1_p, p2_p, p0_eta, p1_eta, p2_eta, SPDhits
# Shape: (855819, 46)
#           LifeTime      dira  FlightDistance  FlightDistanceError        IP  \
# id
# 14711831  0.001273  0.999816        8.569642             0.310039  0.197893
# 16316387  0.000661  0.999954        7.061379             0.348772  0.067430
# 6771382   0.000889  0.999999        6.502967             0.273914  0.011020
# 686045    0.001295  0.999301        7.838184             0.325697  0.388636
# 8755882   0.001714  0.999805        7.064559             0.113440  0.154421
#
#               IPSig  VertexChi2           pt   DOCAone   DOCAtwo   ...     \
# id                                                                 ...
# 14711831   5.183939    2.286117   687.479248  0.022301  0.050763   ...
# 16316387   6.316281    3.865824  5691.845703  0.002455  0.037633   ...
# 6771382    0.865816    1.004631  5429.225586  0.002753  0.036379   ...
# 686045    11.391245   10.345356   661.717834  0.008163  0.436003   ...
# 8755882   13.925871   12.951378  3885.417969  0.066317  0.052183   ...
#
#                 p0_pt        p1_pt        p2_pt          p0_p          p1_p  \
# id
# 14711831   508.926514   306.629456   714.222717  30300.734375   5662.158691
# 16316387   943.130676  3287.291260  1563.593994   6160.323730  43781.566406
# 6771382   2886.055908  2216.936279   598.068359  26387.134766  15534.978516
# 686045     461.727753   357.967560  1118.084229   5451.857422  10281.403320
# 8755882   1773.747925  1643.278198   711.572205   7724.954590  12830.546875
#
#                   p2_p    p0_eta    p1_eta    p2_eta  SPDhits
# id
# 14711831   7406.368164  4.779700  3.608334  3.029715      705
# 16316387  19728.500000  2.563915  3.280884  3.226650      907
# 6771382    6504.145020  2.903129  2.634985  3.077517      213
# 686045    23722.742188  3.160085  4.050494  3.747409      275
# 8755882    6008.145996  2.151059  2.744157  2.823017      357
#
# [5 rows x 46 columns]

# %% [markdown]
# # Train simple model using part of the training sample

# %%
train, test = train_test_split(train_ada, train_size=0.7, random_state=13)
# Out:
# C:\Users\Kiko-PC\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# Let's chose features to train a model

# %%
variables = list(set(train_ada.columns) - {'id', 'signal', 'mass', 'production', 'min_ANNmuon'})
print (variables)
# Out:
# ['DOCAtwo', 'isolationf', 'FlightDistanceError', 'p2_IP', 'p0_track_Chi2Dof', 'p0_IP', 'isolationa', 'LifeTime', 'p2_pt', 'CDF1', 'p1_pt', 'isolationb', 'p1_eta', 'dira', 'DOCAone', 'p1_IsoBDT', 'p2_IPSig', 'IP_p0p2', 'pt', 'p1_p', 'p2_p', 'p1_track_Chi2Dof', 'p1_IPSig', 'iso', 'VertexChi2', 'p2_eta', 'CDF2', 'CDF3', 'ISO_SumBDT', 'p0_pt', 'IP', 'IPSig', 'p1_IP', 'isolationd', 'FlightDistance', 'DOCAthree', 'IP_p1p2', 'p0_IPSig', 'p0_IsoBDT', 'p0_p', 'isolatione', 'p0_eta', 'isolationc', 'p2_IsoBDT', 'p2_track_Chi2Dof', 'SPDhits']

# %%
train.head
# Out:
# <bound method NDFrame.head of              id  LifeTime      dira  FlightDistance  FlightDistanceError  \
# 56520   5100597  0.000759  1.000000       20.195753             0.796748
# 13514  10396501  0.000733  0.999244        5.118261             0.417443
# 35888  10926624  0.001044  0.999998       10.196308             0.390218
# 18577  13432904  0.000895  0.999973       19.234514             1.236785
# 52205   5637740  0.002830  0.999988       74.620522             1.450999
# 54388  13927885  0.001435  1.000000       27.581367             0.391214
# 62630  16348346  0.000763  1.000000       12.846588             0.477072
# 56837  11785098  0.000686  0.999993        5.995281             0.336078
# 22125   4791501  0.000586  0.998965        1.971580             0.158385
# 65137  10872221  0.002365  1.000000       34.235226             0.332315
# 21630   7417366  0.000374  0.999955        6.925420             0.772374
# 24357   9735867  0.000811  0.999610        6.931185             0.260633
# 44428  18326708  0.001482  0.999985       13.061941             0.407187
# 42346     83837  0.001094  1.000000       24.667198             0.428114
# 24442  10730877  0.000947  0.999943       10.444510             0.196019
# 48476  10427354  0.001888  1.000000       35.225540             0.485063
# 2848    5090625  0.000935  0.999043       10.274070             0.440759
# 56369   5003013  0.001198  0.999998        9.369856             0.306312
# 31895  14508771  0.000496  0.999941        2.285184             0.198380
# 36831  11031705  0.001699  0.999999        7.933231             0.156943
# 15394   8048078  0.002216  0.999991       32.964523             1.198171
# 2774    7027736  0.000910  0.998458        7.999359             0.462609
# 64662   2806514  0.001823  0.999983        8.552221             0.145548
# 42997  17292013  0.000540  0.999999       10.302952             0.896965
# 25012  12455940  0.000651  0.999400        3.172435             0.145718
# 50862   3354760  0.001059  0.999999       15.227979             0.397604
# 10978   1929009  0.000749  0.999837        7.744363             0.497275
# 9327   10062791  0.000348  0.999935        2.428968             0.263964
# 29318   7887614  0.000931  0.999903        8.244575             0.356038
# 37968  16054267  0.001242  0.999975        7.493544             0.138341
# ...         ...       ...       ...             ...                  ...
# 15615  15294532  0.005483  0.999998       96.977814             0.302519
# 37400   7474843  0.000550  0.999974        3.338392             0.295105
# 31025  14236081  0.001007  0.999999       16.755596             0.664753
# 53114  15795234  0.000715  0.999997       10.102378             1.438691
# 54963   3573952  0.001044  0.999989        9.475407             0.536383
# 62584    357425  0.000813  0.999999        7.808603             0.383758
# 15028   1654252  0.000708  0.999989        4.858184             0.486913
# 38202   2690369  0.000423  0.999999        8.415589             0.591589
# 56616  11826145  0.002571  0.999995       33.387386             0.351793
# 57355   5432324  0.000697  0.999997        3.160539             0.125170
# 32843  13152845  0.000919  0.999999        5.686682             0.172394
# 33781   8459022  0.000433  0.999986        4.869520             0.397921
# 17811   9020228  0.001469  0.999997       15.028892             0.368574
# 22677  15507972  0.000900  0.999983        5.801569             0.237526
# 44192   8276058  0.001919  0.999936       16.255672             0.221892
# 10057  12645652  0.001006  0.999639        5.844105             0.249459
# 65098   5732549  0.002000  0.999995       18.517334             0.242133
# 12237   5755069  0.000700  0.999999       26.540636             1.254990
# 51429  13389004  0.002651  0.999995       18.119741             0.260803
# 50614   8856254  0.000378  0.999911        3.319669             0.319940
# 64430  17148365  0.000905  0.999988        9.866392             0.203486
# 59330   1205277  0.001442  0.999986        7.119362             0.250199
# 55934    537294  0.000601  0.999998        8.626346             0.447305
# 13556  10288041  0.001058  0.999997       23.472692             0.635738
# 58266  17087406  0.001994  0.999996       31.119791             0.895552
# 36794   6902374  0.001201  1.000000       53.381378             1.506938
# 25324   4683462  0.001310  0.999687        9.665164             0.386610
# 65689  11329131  0.001001  0.999999       14.225611             0.265180
# 33634    655796  0.000841  0.999954       12.802187             0.455519
# 47280   4418283  0.000681  0.999914        3.355349             0.227096
#
#              IP      IPSig  VertexChi2            pt   DOCAone     ...       \
# 56520  0.007034   0.491647    1.353189  10099.736328  0.030664     ...
# 13514  0.191408   9.899615   11.493479   2217.499268  0.118355     ...
# 35888  0.018878   1.010691    0.184407   3002.109131  0.009387     ...
# 18577  0.213456  10.716880   11.469318   3172.664795  0.100612     ...
# 52205  0.359582  13.736321   11.836902   4432.305176  0.035734     ...
# 54388  0.006121   0.576214    3.648028   8039.824707  0.020654     ...
# 62630  0.011312   1.066214    2.652548   7294.102539  0.002112     ...
# 56837  0.021433   1.299585    3.811590   4406.903320  0.026535     ...
# 22125  0.146789   7.032411    3.108829   2115.649170  0.009240     ...
# 65137  0.023355   2.077209    1.860577   6542.702148  0.000154     ...
# 21630  0.059382   4.188336    1.639182   5928.531738  0.013549     ...
# 24357  0.174460  12.018112   12.075116   3733.801270  0.029563     ...
# 44428  0.069494   5.274657   13.380024   6252.710449  0.044049     ...
# 42346  0.019340   1.801329    5.092551  12411.329102  0.016345     ...
# 24442  0.106532  12.832859    1.688568   7885.670410  0.019111     ...
# 48476  0.004331   0.312428    5.257170   7721.750488  0.041787     ...
# 2848   0.249331  15.265265    7.773726   3204.715820  0.074057     ...
# 56369  0.019058   1.323938    4.622720   3936.453613  0.077962     ...
# 31895  0.024592   1.864479    0.666716   3861.247314  0.001843     ...
# 36831  0.011026   0.763868   12.662420   3837.685791  0.039321     ...
# 15394  0.142583   7.070989    8.270851   2959.345947  0.370787     ...
# 2774   0.221031  13.869136    8.819022   3687.440186  0.031709     ...
# 64662  0.050244   4.536352    1.401317   4959.387695  0.018544     ...
# 42997  0.016611   0.922131    3.504110   4126.799316  0.007406     ...
# 25012  0.106284  10.334025    0.448447   4713.312012  0.013344     ...
# 50862  0.017054   1.543415    0.514249   5973.855957  0.005689     ...
# 10978  0.147627  10.669419    1.750252   3538.964600  0.001819     ...
# 9327   0.028529   2.020653    4.146126   5227.990723  0.033184     ...
# 29318  0.122501   3.628499    6.409559   3842.383301  0.039148     ...
# 37968  0.052653   4.033906   12.379508   4784.350098  0.028554     ...
# ...         ...        ...         ...           ...       ...     ...
# 15615  0.204115  14.248525    1.699866   4488.583008  0.020030     ...
# 37400  0.024741   1.490424    8.603230   2779.843018  0.030300     ...
# 31025  0.021504   1.305798    1.343738   4657.249023  0.012889     ...
# 53114  0.024803   0.872724    4.176534   2513.153564  0.163156     ...
# 54963  0.044921   2.226573    3.200811   3517.247803  0.000918     ...
# 62584  0.010386   0.761541    2.327304   5866.407227  0.014755     ...
# 15028  0.023508   1.495344    7.015014   2856.623779  0.236266     ...
# 38202  0.011824   0.826014    3.120268  12647.801758  0.002783     ...
# 56616  0.103604   7.735230    6.090466   6047.229004  0.010915     ...
# 57355  0.007955   0.488515    1.163103   4372.271973  0.014427     ...
# 32843  0.007373   0.623298    1.122343   6011.571777  0.003015     ...
# 33781  0.023981   1.872445    1.792765   5675.886719  0.011539     ...
# 17811  0.035591   2.873162    2.450307   4268.801270  0.043762     ...
# 22677  0.034164   2.582810    8.621917   4751.753418  0.027889     ...
# 44192  0.187838  11.516005    2.579426   7883.793457  0.000607     ...
# 10057  0.170218  11.270926    1.584612   4135.388184  0.017461     ...
# 65098  0.058055   4.911526    1.088302   5451.877441  0.019302     ...
# 12237  0.036249   3.326634   14.707846  14864.284180  0.014371     ...
# 51429  0.058271   3.506544   11.370192   5247.448242  0.076174     ...
# 50614  0.040972   3.482448    1.187479   5903.333496  0.015021     ...
# 64430  0.046954   4.015168    4.598629   6841.058105  0.035572     ...
# 59330  0.036529   2.028940    4.028448   2728.669434  0.110037     ...
# 55934  0.016830   1.490887    1.462183   6696.253906  0.008878     ...
# 13556  0.057829   5.006613    6.582240   8756.220703  0.036601     ...
# 58266  0.091764   4.821190    2.189457   2959.179199  0.050508     ...
# 36794  0.017234   1.126830    1.715984  10446.678711  0.055752     ...
# 25324  0.221156  11.415130   13.547439   2229.916016  0.066581     ...
# 65689  0.024772   2.172442    5.728966  12048.512695  0.017801     ...
# 33634  0.122119   5.576184    0.707405   5187.702148  0.010644     ...
# 47280  0.039399   2.578463    4.952875   4046.685303  0.046489     ...
#
#                 p1_p           p2_p    p0_eta    p1_eta    p2_eta  SPDhits  \
# 56520   54594.738281   91263.117188  3.451955  3.520630  3.378501      233
# 13514   24461.876953    3798.012939  3.469964  3.475827  3.005881      450
# 35888   12760.266602   30162.423828  3.350111  3.090407  4.142528      331
# 18577   57057.406250   28831.949219  4.317383  4.017044  4.519739      369
# 52205   42211.164062   99298.960938  3.948832  4.131541  4.254098      131
# 54388   48905.191406   49939.167969  3.029924  3.413313  3.355262      274
# 62630   59127.832031    7284.793945  3.407478  3.197402  3.554927      349
# 56837   19948.220703   22739.923828  2.977889  2.823614  3.681759      218
# 22125    9256.262695    3417.763428  3.234830  2.381290  2.963360       68
# 65137   36063.867188   16232.023438  3.493969  3.025116  3.416822      232
# 21630   26153.279297   61320.898438  3.374460  3.340491  3.740896      438
# 24357   37801.625000    3430.747803  2.936867  3.554888  2.741790      157
# 44428   25381.210938    4472.433105  2.761516  2.761228  3.149766      340
# 42346   47827.562500   58668.085938  3.150857  2.932456  3.133984      404
# 24442   16862.611328   32113.746094  3.026231  2.829313  2.575935      356
# 48476   56730.980469   19277.746094  3.681823  3.248527  3.178988      152
# 2848    22161.105469   26634.449219  3.569413  3.224612  4.183456      491
# 56369    9925.414062   32147.576172  3.007970  2.934681  3.122917      158
# 31895   10005.173828    9656.486328  2.390625  2.352905  3.417791       86
# 36831    9777.474609    5296.166504  2.647769  2.354169  3.113643      429
# 15394   14041.846680   61198.832031  3.646671  3.798599  3.969553      261
# 2774    10339.001953   29503.613281  4.063714  3.196490  3.131425      239
# 64662    7851.562500   13935.312500  2.474449  2.496926  2.240610      290
# 42997   58089.359375   27696.085938  3.857238  4.204202  3.650907      115
# 25012   11146.143555   13593.750000  2.047384  2.526437  2.646716      311
# 50862   37800.144531   21129.722656  3.358089  3.369032  3.180086      177
# 10978   40331.050781    5604.988770  3.381094  3.619200  2.848318      325
# 9327    17110.974609   17995.191406  3.311848  2.630568  2.704901      360
# 29318   15475.082031   29079.833984  3.127938  2.978314  3.421745       57
# 37968    8990.407227   23208.275391  2.190871  2.739864  2.718171       94
# ...              ...            ...       ...       ...       ...      ...
# 15615   66093.851562   25690.779297  3.289771  4.117846  4.009099      565
# 37400    6622.289062   16613.117188  3.896646  2.899609  2.905242      296
# 31025   55984.164062   13502.529297  3.547923  3.871647  3.417204      289
# 53114   11054.596680   53095.968750  4.424278  3.697023  3.981677      307
# 54963   20912.011719   18027.357422  3.280760  3.089841  3.898605      456
# 62584   39570.289062    4541.159668  3.106374  2.864070  3.016040       68
# 15028   30705.449219    4369.962402  4.128985  3.205036  2.891298      607
# 38202   23320.134766   85853.179688  3.073349  3.170047  2.850613      196
# 56616   34126.707031   24846.968750  2.997297  3.494515  3.084882      168
# 57355    8248.562500   14490.971680  2.209357  2.175264  2.801952      186
# 32843   12411.934570   19467.652344  2.136961  2.632737  2.454322      112
# 33781   31377.726562   21925.039062  3.049293  2.965229  3.542057      356
# 17811   16916.640625   38606.121094  2.991425  3.389484  3.363377      402
# 22677   28282.707031    8867.833008  2.779172  2.883277  2.500719      272
# 44192   10296.753906   33183.824219  2.400182  2.660375  2.498536      183
# 10057    8731.212891   20008.626953  2.697158  2.582266  2.929502      363
# 65098   25609.121094    8604.867188  3.352992  2.800344  2.834625      240
# 12237  139049.453125   64533.222656  3.302030  3.354980  3.396735      341
# 51429   27360.367188    8563.338867  2.400387  2.624721  3.392057       87
# 50614   20362.509766   17453.240234  3.291588  2.750688  2.686296      107
# 64430   19491.492188   19441.154297  3.214678  2.663007  2.907835      234
# 59330   16680.544922    7214.886230  3.449038  2.792809  2.898949      153
# 55934   39017.613281   39734.449219  3.639280  3.203859  3.163113      201
# 13556   37644.375000   71279.531250  3.684690  3.140812  3.362576      280
# 58266   48727.175781   16733.919922  3.903710  4.077585  3.896646      532
# 36794   47796.828125  192102.234375  3.702262  3.775385  3.994928      163
# 25324   11502.669922   19443.033203  3.906793  3.212381  3.404747      279
# 65689   34876.226562   37540.605469  2.848061  2.622234  2.568145      305
# 33634   37554.074219   17756.619141  3.441692  3.521940  3.533674       55
# 47280   12252.117188    6961.712402  2.666172  2.334536  3.632062      348
#
#        production  signal         mass  min_ANNmuon
# 56520           1       1  1782.249512     0.492647
# 13514         -99       0  1859.000977     0.734995
# 35888           1       1  1771.439819     0.355267
# 18577         -99       0  1668.386963     0.379376
# 52205           8       1  1771.005981     0.809363
# 54388           1       1  1776.285522     0.565756
# 62630           1       1  1772.763184     0.618902
# 56837           1       1  1778.275513     0.750438
# 22125         -99       0  1680.344971     0.273873
# 65137           2       1  1781.856445     0.934725
# 21630         -99       0  1722.062012     0.241678
# 24357         -99       0  1882.564941     0.203943
# 44428           4       1  1782.775269     0.650318
# 42346           4       1  1772.376709     0.927643
# 24442         -99       0  1627.244019     0.300983
# 48476           1       1  1787.172852     0.697164
# 2848          -99       0  1679.246948     0.349586
# 56369           1       1  1769.295044     0.388201
# 31895           1       1  1779.256348     0.516808
# 36831           1       1  1776.740601     0.649868
# 15394         -99       0  1682.113037     0.298585
# 2774          -99       0  1816.468018     0.716402
# 64662           1       1  1771.905273     0.464445
# 42997           1       1  1788.761108     0.528904
# 25012         -99       0  1811.368042     0.489631
# 50862           1       1  1782.040039     0.734848
# 10978         -99       0  1755.489990     0.517948
# 9327          -99       0  1845.743042     0.274382
# 29318           1       1  1757.955933     0.673347
# 37968           4       1  1775.076172     0.826237
# ...           ...     ...          ...          ...
# 15615         -99       0  1878.761963     0.366386
# 37400           1       1  1772.528809     0.643618
# 31025           1       1  1772.182495     0.667008
# 53114           1       1  1769.520996     0.232209
# 54963           1       1  1779.400024     0.475894
# 62584           1       1  1776.061157     0.672185
# 15028         -99       0  1942.603027     0.608732
# 38202           1       1  1778.450439     0.906304
# 56616           4       1  1776.940186     0.920389
# 57355           1       1  1773.059448     0.683244
# 32843           1       1  1765.933350     0.838951
# 33781           1       1  1778.393066     0.672490
# 17811         -99       0  1852.770996     0.362454
# 22677         -99       0  1881.947021     0.296920
# 44192           4       1  1770.601196     0.874702
# 10057         -99       0  1871.548950     0.333789
# 65098           5       1  1780.437134     0.318253
# 12237         -99       0  1718.397949     0.527210
# 51429           1       1  1774.397827     0.521904
# 50614           1       1  1776.371216     0.791610
# 64430           1       1  1776.621704     0.818689
# 59330           1       1  1772.988647     0.699896
# 55934           1       1  1787.413208     0.354050
# 13556         -99       0  1636.775024     0.565154
# 58266           1       1  1786.133911     0.270691
# 36794           2       1  1793.029785     0.802796
# 25324         -99       0  1817.534058     0.205893
# 65689           1       1  1776.446045     0.298218
# 33634           1       1  1771.007202     0.708820
# 47280           1       1  1771.722290     0.102802
#
# [47287 rows x 51 columns]>

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# training_preprocess = scaler.fit_transform(train[variables].values)

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(hidden_layer_sizes=(32, 16, 8), activation='relu',  batch_size='auto',
              learning_rate='adaptive', learning_rate_init=0.001, max_iter=500, early_stopping = True, verbose=1, n_iter_no_change=100
              )

clf.fit(train[variables],  train['signal'])
# Out:
# Iteration 1, loss = 9.21413693
# Validation score: 0.546839
# Iteration 2, loss = 6.71367622
# Validation score: 0.614506
# Iteration 3, loss = 5.82880634
# Validation score: 0.584479
# Iteration 4, loss = 5.07043706
# Validation score: 0.620216
# Iteration 5, loss = 4.73045727
# Validation score: 0.650455
# Iteration 6, loss = 3.93849967
# Validation score: 0.670332
# Iteration 7, loss = 4.04137068
# Validation score: 0.624233
# Iteration 8, loss = 3.96601321
# Validation score: 0.677522
# Iteration 9, loss = 3.72812507
# Validation score: 0.675407
# Iteration 10, loss = 3.54693426
# Validation score: 0.667583
# Iteration 11, loss = 3.14467592
# Validation score: 0.671812
# Iteration 12, loss = 2.59211707
# Validation score: 0.657644
# Iteration 13, loss = 3.35908319
# Validation score: 0.727004
# Iteration 14, loss = 2.81038135
# Validation score: 0.566716
# Iteration 15, loss = 2.69301409
# Validation score: 0.729753
# Iteration 16, loss = 2.54913454
# Validation score: 0.716642
# Iteration 17, loss = 2.19504383
# Validation score: 0.670121
# Iteration 18, loss = 3.06751755
# Validation score: 0.745612
# Iteration 19, loss = 2.39406742
# Validation score: 0.735674
# Iteration 20, loss = 2.28622580
# Validation score: 0.722563
# Iteration 21, loss = 2.39517800
# Validation score: 0.742652
# Iteration 22, loss = 2.84719166
# Validation score: 0.644957
# Iteration 23, loss = 2.27825787
# Validation score: 0.764644
# Iteration 24, loss = 2.27381363
# Validation score: 0.722774
# Iteration 25, loss = 2.34428785
# Validation score: 0.714316
# Iteration 26, loss = 1.80360938
# Validation score: 0.586382
# Iteration 27, loss = 2.25095431
# Validation score: 0.694650
# Iteration 28, loss = 1.76742456
# Validation score: 0.695073
# Iteration 29, loss = 1.88768166
# Validation score: 0.755551
# Iteration 30, loss = 2.21468931
# Validation score: 0.720448
# Iteration 31, loss = 2.01501446
# Validation score: 0.757031
# Iteration 32, loss = 2.17076262
# Validation score: 0.787693
# Iteration 33, loss = 1.98225372
# Validation score: 0.765490
# Iteration 34, loss = 2.06268927
# Validation score: 0.659125
# Iteration 35, loss = 1.59043839
# Validation score: 0.655530
# Iteration 36, loss = 1.74818222
# Validation score: 0.767816
# Iteration 37, loss = 1.64381324
# Validation score: 0.762318
# Iteration 38, loss = 1.93873642
# Validation score: 0.768450
# Iteration 39, loss = 1.85683787
# Validation score: 0.738000
# Iteration 40, loss = 1.65322017
# Validation score: 0.764855
# Iteration 41, loss = 1.39037134
# Validation score: 0.790019
# Iteration 42, loss = 2.31616256
# Validation score: 0.796574
# Iteration 43, loss = 1.29753882
# Validation score: 0.742440
# Iteration 44, loss = 1.39198563
# Validation score: 0.802707
# Iteration 45, loss = 1.60188863
# Validation score: 0.766547
# Iteration 46, loss = 1.28393465
# Validation score: 0.658490
# Iteration 47, loss = 1.35664703
# Validation score: 0.591034
# Iteration 48, loss = 1.52148194
# Validation score: 0.777966
# Iteration 49, loss = 1.48264369
# Validation score: 0.754916
# Iteration 50, loss = 1.48313068
# Validation score: 0.744555
# Iteration 51, loss = 1.12461933
# Validation score: 0.644745
# Iteration 52, loss = 1.47198017
# Validation score: 0.764432
# Iteration 53, loss = 1.26878665
# Validation score: 0.719602
# Iteration 54, loss = 1.63384953
# Validation score: 0.772679
# Iteration 55, loss = 1.08382945
# Validation score: 0.794460
# Iteration 56, loss = 1.08874323
# Validation score: 0.767816
# Iteration 57, loss = 1.59519441
# Validation score: 0.748573
# Iteration 58, loss = 1.19806365
# Validation score: 0.762952
# Iteration 59, loss = 1.20490215
# Validation score: 0.590400
# Iteration 60, loss = 1.05131833
# Validation score: 0.793825
# Iteration 61, loss = 1.29075388
# Validation score: 0.800592
# Iteration 62, loss = 1.08063909
# Validation score: 0.804187
# Iteration 63, loss = 0.95481893
# Validation score: 0.747092
# Iteration 64, loss = 1.00569750
# Validation score: 0.777120
# Iteration 65, loss = 1.11372402
# Validation score: 0.776274
# Iteration 66, loss = 1.29210098
# Validation score: 0.720660
# Iteration 67, loss = 0.83704411
# Validation score: 0.742440
# Iteration 68, loss = 0.74675453
# Validation score: 0.732079
# Iteration 69, loss = 1.16474724
# Validation score: 0.820681
# Iteration 70, loss = 0.81559879
# Validation score: 0.771622
# Iteration 71, loss = 1.31714491
# Validation score: 0.762318
# Iteration 72, loss = 0.70073526
# Validation score: 0.803764
# Iteration 73, loss = 0.94534079
# Validation score: 0.724255
# Iteration 74, loss = 0.66174946
# Validation score: 0.776697
# Iteration 75, loss = 0.69686669
# Validation score: 0.716642
# Iteration 76, loss = 0.69514530
# Validation score: 0.809051
# Iteration 77, loss = 0.68816501
# Validation score: 0.789596
# Iteration 78, loss = 0.72599792
# Validation score: 0.799323
# Iteration 79, loss = 0.64318975
# Validation score: 0.816240
# Iteration 80, loss = 0.80809811
# Validation score: 0.813703
# Iteration 81, loss = 0.71611276
# Validation score: 0.756185
# Iteration 82, loss = 0.61869825
# Validation score: 0.810954
# Iteration 83, loss = 0.71422846
# Validation score: 0.812434
# Iteration 84, loss = 0.70987087
# Validation score: 0.744978
# Iteration 85, loss = 0.55616190
# Validation score: 0.784310
# Iteration 86, loss = 0.65322306
# Validation score: 0.792345
# Iteration 87, loss = 0.57429252
# Validation score: 0.819624
# Iteration 88, loss = 0.62305821
# Validation score: 0.788116
# Iteration 89, loss = 0.51059530
# Validation score: 0.821950
# Iteration 90, loss = 0.53431091
# Validation score: 0.789808
# Iteration 91, loss = 0.56085992
# Validation score: 0.783675
# Iteration 92, loss = 0.53029609
# Validation score: 0.783887
# Iteration 93, loss = 0.53438986
# Validation score: 0.770142
# Iteration 94, loss = 0.50126288
# Validation score: 0.805879
# Iteration 95, loss = 0.49771974
# Validation score: 0.790865
# Iteration 96, loss = 0.52254855
# Validation score: 0.808416
# Iteration 97, loss = 0.49520886
# Validation score: 0.757243
# Iteration 98, loss = 0.46743850
# Validation score: 0.814337
# Iteration 99, loss = 0.47480145
# Validation score: 0.756608
# Iteration 100, loss = 0.48920387
# Validation score: 0.824064
# Iteration 101, loss = 0.50486344
# Validation score: 0.798055
# Iteration 102, loss = 0.44128200
# Validation score: 0.834003
# Iteration 103, loss = 0.45628460
# Validation score: 0.818778
# Iteration 104, loss = 0.44124962
# Validation score: 0.832734
# Iteration 105, loss = 0.47029720
# Validation score: 0.833157
# Iteration 106, loss = 0.44358338
# Validation score: 0.819412
# Iteration 107, loss = 0.45289278
# Validation score: 0.820258
# Iteration 108, loss = 0.44692552
# Validation score: 0.787059
# Iteration 109, loss = 0.44377605
# Validation score: 0.812011
# Iteration 110, loss = 0.48566843
# Validation score: 0.823218
# Iteration 111, loss = 0.43828238
# Validation score: 0.784944
# Iteration 112, loss = 0.44992300
# Validation score: 0.791499
# Iteration 113, loss = 0.47435933
# Validation score: 0.791076
# Iteration 114, loss = 0.46997760
# Validation score: 0.831465
# Iteration 115, loss = 0.42033478
# Validation score: 0.822584
# Iteration 116, loss = 0.45839382
# Validation score: 0.811165
# Iteration 117, loss = 0.43543278
# Validation score: 0.810108
# Iteration 118, loss = 0.42284415
# Validation score: 0.829351
# Iteration 119, loss = 0.43652789
# Validation score: 0.806090
# Iteration 120, loss = 0.43103596
# Validation score: 0.823641
# Iteration 121, loss = 0.44252687
# Validation score: 0.831677
# Iteration 122, loss = 0.41821509
# Validation score: 0.798055
# Iteration 123, loss = 0.41133874
# Validation score: 0.831888
# Iteration 124, loss = 0.41852246
# Validation score: 0.800169
# Iteration 125, loss = 0.44037736
# Validation score: 0.826179
# Iteration 126, loss = 0.43273313
# Validation score: 0.820258
# Iteration 127, loss = 0.42972933
# Validation score: 0.825756
# Iteration 128, loss = 0.41757307
# Validation score: 0.815606
# Iteration 129, loss = 0.43427518
# Validation score: 0.832946
# Iteration 130, loss = 0.41462695
# Validation score: 0.822584
# Iteration 131, loss = 0.41882446
# Validation score: 0.819201
# Iteration 132, loss = 0.43219374
# Validation score: 0.817720
# Iteration 133, loss = 0.42635948
# Validation score: 0.728907
# Iteration 134, loss = 0.42450736
# Validation score: 0.819201
# Iteration 135, loss = 0.41080421
# Validation score: 0.831888
# Iteration 136, loss = 0.40811114
# Validation score: 0.818778
# Iteration 137, loss = 0.43104962
# Validation score: 0.806513
# Iteration 138, loss = 0.43182885
# Validation score: 0.821950
# Iteration 139, loss = 0.41579008
# Validation score: 0.815817
# Iteration 140, loss = 0.41523706
# Validation score: 0.837809
# Iteration 141, loss = 0.41752558
# Validation score: 0.841404
# Iteration 142, loss = 0.43440098
# Validation score: 0.827025
# Iteration 143, loss = 0.40630271
# Validation score: 0.839078
# Iteration 144, loss = 0.41882026
# Validation score: 0.839289
# Iteration 145, loss = 0.41378286
# Validation score: 0.839712
# Iteration 146, loss = 0.40701937
# Validation score: 0.839501
# Iteration 147, loss = 0.40423964
# Validation score: 0.835272
# Iteration 148, loss = 0.41724494
# Validation score: 0.804610
# Iteration 149, loss = 0.40053495
# Validation score: 0.825967
# Iteration 150, loss = 0.41078608
# Validation score: 0.816452
# Iteration 151, loss = 0.40173017
# Validation score: 0.824699
# Iteration 152, loss = 0.40483442
# Validation score: 0.809896
# Iteration 153, loss = 0.41352334
# Validation score: 0.806302
# Iteration 154, loss = 0.39979815
# Validation score: 0.839924
# Iteration 155, loss = 0.39956171
# Validation score: 0.829774
# Iteration 156, loss = 0.39918539
# Validation score: 0.817932
# Iteration 157, loss = 0.39246176
# Validation score: 0.803553
# Iteration 158, loss = 0.40577091
# Validation score: 0.798900
# Iteration 159, loss = 0.43578595
# Validation score: 0.798055
# Iteration 160, loss = 0.40257980
# Validation score: 0.833157
# Iteration 161, loss = 0.40472057
# Validation score: 0.820892
# Iteration 162, loss = 0.40409233
# Validation score: 0.792557
# Iteration 163, loss = 0.40226860
# Validation score: 0.831043
# Iteration 164, loss = 0.40898284
# Validation score: 0.839924
# Iteration 165, loss = 0.40347573
# Validation score: 0.793402
# Iteration 166, loss = 0.40308942
# Validation score: 0.835483
# Iteration 167, loss = 0.39523751
# Validation score: 0.841827
# Iteration 168, loss = 0.40447737
# Validation score: 0.834637
# Iteration 169, loss = 0.41332192
# Validation score: 0.838655
# Iteration 170, loss = 0.40173468
# Validation score: 0.842673
# Iteration 171, loss = 0.40156605
# Validation score: 0.829351
# Iteration 172, loss = 0.39336750
# Validation score: 0.842884
# Iteration 173, loss = 0.39187813
# Validation score: 0.823641
# Iteration 174, loss = 0.38922355
# Validation score: 0.842250
# Iteration 175, loss = 0.39547424
# Validation score: 0.830197
# Iteration 176, loss = 0.40660643
# Validation score: 0.840135
# Iteration 177, loss = 0.40332589
# Validation score: 0.842673
# Iteration 178, loss = 0.39916534
# Validation score: 0.842461
# Iteration 179, loss = 0.40365845
# Validation score: 0.836118
# Iteration 180, loss = 0.41812739
# Validation score: 0.838655
# Iteration 181, loss = 0.41077032
# Validation score: 0.835695
# Iteration 182, loss = 0.38877498
# Validation score: 0.800381
# Iteration 183, loss = 0.40814392
# Validation score: 0.838867
# Iteration 184, loss = 0.39591245
# Validation score: 0.836752
# Iteration 185, loss = 0.39568657
# Validation score: 0.833791
# Iteration 186, loss = 0.40427764
# Validation score: 0.827025
# Iteration 187, loss = 0.39720789
# Validation score: 0.827025
# Iteration 188, loss = 0.39995754
# Validation score: 0.822584
# Iteration 189, loss = 0.39716512
# Validation score: 0.829774
# Iteration 190, loss = 0.40595589
# Validation score: 0.837386
# Iteration 191, loss = 0.39460973
# Validation score: 0.844787
# Iteration 192, loss = 0.40400261
# Validation score: 0.826179
# Iteration 193, loss = 0.43676331
# Validation score: 0.823430
# Iteration 194, loss = 0.40503479
# Validation score: 0.837386
# Iteration 195, loss = 0.39063505
# Validation score: 0.827448
# Iteration 196, loss = 0.38300768
# Validation score: 0.840135
# Iteration 197, loss = 0.38344338
# Validation score: 0.843307
# Iteration 198, loss = 0.39398492
# Validation score: 0.841827
# Iteration 199, loss = 0.38952214
# Validation score: 0.826179
# Iteration 200, loss = 0.39719660
# Validation score: 0.823641
# Iteration 201, loss = 0.39825736
# Validation score: 0.848171
# Iteration 202, loss = 0.40765945
# Validation score: 0.834637
# Iteration 203, loss = 0.38386351
# Validation score: 0.803975
# Iteration 204, loss = 0.40532531
# Validation score: 0.816875
# Iteration 205, loss = 0.39937233
# Validation score: 0.824276
# Iteration 206, loss = 0.39507466
# Validation score: 0.842461
# Iteration 207, loss = 0.39889559
# Validation score: 0.835272
# Iteration 208, loss = 0.39726203
# Validation score: 0.840770
# Iteration 209, loss = 0.38480897
# Validation score: 0.824064
# Iteration 210, loss = 0.39330077
# Validation score: 0.843307
# Iteration 211, loss = 0.39638684
# Validation score: 0.834426
# Iteration 212, loss = 0.39983466
# Validation score: 0.844153
# Iteration 213, loss = 0.38692602
# Validation score: 0.797632
# Iteration 214, loss = 0.40747288
# Validation score: 0.839078
# Iteration 215, loss = 0.38709103
# Validation score: 0.829562
# Iteration 216, loss = 0.38722964
# Validation score: 0.829985
# Iteration 217, loss = 0.38432292
# Validation score: 0.844576
# Iteration 218, loss = 0.38012294
# Validation score: 0.810742
# Iteration 219, loss = 0.40055697
# Validation score: 0.835483
# Iteration 220, loss = 0.39384913
# Validation score: 0.812857
# Iteration 221, loss = 0.39521017
# Validation score: 0.844999
# Iteration 222, loss = 0.39093653
# Validation score: 0.843307
# Iteration 223, loss = 0.40341225
# Validation score: 0.801015
# Iteration 224, loss = 0.38417152
# Validation score: 0.839712
# Iteration 225, loss = 0.54652958
# Validation score: 0.641573
# Iteration 226, loss = 0.55137631
# Validation score: 0.767816
# Iteration 227, loss = 0.43168652
# Validation score: 0.841193
# Iteration 228, loss = 0.39813520
# Validation score: 0.833580
# Iteration 229, loss = 0.38616177
# Validation score: 0.827871
# Iteration 230, loss = 0.38255944
# Validation score: 0.831043
# Iteration 231, loss = 0.39254800
# Validation score: 0.826179
# Iteration 232, loss = 0.39739741
# Validation score: 0.843730
# Iteration 233, loss = 0.39178583
# Validation score: 0.834849
# Iteration 234, loss = 0.38188869
# Validation score: 0.845210
# Iteration 235, loss = 0.39548757
# Validation score: 0.784098
# Iteration 236, loss = 0.49065167
# Validation score: 0.805244
# Iteration 237, loss = 0.45841752
# Validation score: 0.805456
# Iteration 238, loss = 0.45373144
# Validation score: 0.815817
# Iteration 239, loss = 0.44473029
# Validation score: 0.829774
# Iteration 240, loss = 0.43182669
# Validation score: 0.834003
# Iteration 241, loss = 0.41750629
# Validation score: 0.799958
# Iteration 242, loss = 0.41004817
# Validation score: 0.830620
# Iteration 243, loss = 0.41317209
# Validation score: 0.835272
# Iteration 244, loss = 0.40254462
# Validation score: 0.809051
# Iteration 245, loss = 0.41024048
# Validation score: 0.819624
# Iteration 246, loss = 0.40694820
# Validation score: 0.840981
# Iteration 247, loss = 0.41754542
# Validation score: 0.835695
# Iteration 248, loss = 0.39900891
# Validation score: 0.834637
# Iteration 249, loss = 0.41344213
# Validation score: 0.833369
# Iteration 250, loss = 0.41367004
# Validation score: 0.817932
# Iteration 251, loss = 0.39493595
# Validation score: 0.812645
# Iteration 252, loss = 0.39982511
# Validation score: 0.795940
# Iteration 253, loss = 0.39381443
# Validation score: 0.832311
# Iteration 254, loss = 0.39151731
# Validation score: 0.831677
# Iteration 255, loss = 0.39738196
# Validation score: 0.844576
# Iteration 256, loss = 0.40140665
# Validation score: 0.827659
# Iteration 257, loss = 0.38735765
# Validation score: 0.842884
# Iteration 258, loss = 0.39086162
# Validation score: 0.839501
# Iteration 259, loss = 0.38551441
# Validation score: 0.839289
# Iteration 260, loss = 0.39367488
# Validation score: 0.835906
# Iteration 261, loss = 0.38987017
# Validation score: 0.831888
# Iteration 262, loss = 0.39660215
# Validation score: 0.829774
# Iteration 263, loss = 0.38585636
# Validation score: 0.818566
# Iteration 264, loss = 0.38668794
# Validation score: 0.840558
# Iteration 265, loss = 0.39148984
# Validation score: 0.838655
# Iteration 266, loss = 0.38320257
# Validation score: 0.843519
# Iteration 267, loss = 0.40199382
# Validation score: 0.825967
# Iteration 268, loss = 0.38751352
# Validation score: 0.836752
# Iteration 269, loss = 0.38982119
# Validation score: 0.841616
# Iteration 270, loss = 0.38827828
# Validation score: 0.826179
# Iteration 271, loss = 0.38701484
# Validation score: 0.844365
# Iteration 272, loss = 0.38745953
# Validation score: 0.841193
# Iteration 273, loss = 0.40558410
# Validation score: 0.838444
# Iteration 274, loss = 0.38692550
# Validation score: 0.839712
# Iteration 275, loss = 0.40081287
# Validation score: 0.844787
# Iteration 276, loss = 0.38897501
# Validation score: 0.843307
# Iteration 277, loss = 0.38755048
# Validation score: 0.843307
# Iteration 278, loss = 0.38534272
# Validation score: 0.839501
# Iteration 279, loss = 0.39400854
# Validation score: 0.846268
# Iteration 280, loss = 0.38675145
# Validation score: 0.809262
# Iteration 281, loss = 0.39285033
# Validation score: 0.844787
# Iteration 282, loss = 0.38282052
# Validation score: 0.836752
# Iteration 283, loss = 0.38812499
# Validation score: 0.837386
# Iteration 284, loss = 0.38146294
# Validation score: 0.839501
# Iteration 285, loss = 0.39122147
# Validation score: 0.834214
# Iteration 286, loss = 0.39744966
# Validation score: 0.796997
# Iteration 287, loss = 0.38405974
# Validation score: 0.847325
# Iteration 288, loss = 0.38526940
# Validation score: 0.843730
# Iteration 289, loss = 0.38346863
# Validation score: 0.836963
# Iteration 290, loss = 0.38942630
# Validation score: 0.835483
# Iteration 291, loss = 0.38184024
# Validation score: 0.844787
# Iteration 292, loss = 0.39256584
# Validation score: 0.839501
# Iteration 293, loss = 0.37579773
# Validation score: 0.836963
# Iteration 294, loss = 0.38501349
# Validation score: 0.839924
# Iteration 295, loss = 0.38962549
# Validation score: 0.808839
# Iteration 296, loss = 0.39546157
# Validation score: 0.822584
# Iteration 297, loss = 0.38197767
# Validation score: 0.840347
# Iteration 298, loss = 0.38182568
# Validation score: 0.840558
# Iteration 299, loss = 0.39468773
# Validation score: 0.843730
# Iteration 300, loss = 0.39541949
# Validation score: 0.811377
# Iteration 301, loss = 0.38556349
# Validation score: 0.810954
# Iteration 302, loss = 0.38672910
# Validation score: 0.840981
# Validation score did not improve more than tol=0.000100 for 100 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=True, epsilon=1e-08,
#        hidden_layer_sizes=(32, 16, 8), learning_rate='adaptive',
#        learning_rate_init=0.001, max_iter=500, momentum=0.9,
#        n_iter_no_change=100, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=1, warm_start=False)

# %%
# %%time
clf = AdaBoostClassifier(n_estimators=150, learning_rate=0.01, random_state=13,
                             base_estimator=DecisionTreeClassifier(max_depth=25, min_samples_leaf=50, max_features=15,
                                                                    random_state=13))
clf.fit(train[variables], train['signal'])

# %% [markdown]
# # Check model quality on a half of the training sample

# %%
def plot_metrics(y_true, y_pred):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred)
    roc_auc = roc_auc_score(y_true, y_pred)

    plt.plot(fpr, tpr, label='ROC AUC=%f' % roc_auc)
    plt.xlabel("FPR")
    plt.ylabel("TPR")
    plt.legend()
    plt.title("ROC Curve")

# %%
y_pred = clf.predict_proba(test[variables])[:, 1]

plot_metrics(test['signal'], y_pred)
test.shape, y_pred.shape
# Out:
# ((20266, 51), (20266,))

# %% [markdown]
# ROC AUC is just a part of the solution, you also have to make sure that
#
# - the classifier output is not correlated with the mass
# - classifier performs similarily on MC and real data of the normalization channel

# %% [markdown]
# ### Mass correlation check

# %%
df_corr_check = pandas.read_csv("reference/check_correlation.csv")

# %%
df_corr_check.shape
# Out:
# (5514, 48)

# %%
y_pred = clf.predict(df_corr_check[variables])

# %%
 def efficiencies(features, thresholds=None, mask=None, bins=30, labels_dict=None, ignored_sideband=0.0,
                     errors=False, grid_columns=2):
        """
        Efficiencies for spectators
        :param features: using features (if None then use classifier's spectators)
        :type features: None or list[str]
        :param bins: bins for histogram
        :type bins: int or array-like
        :param mask: mask for data, which will be used
        :type mask: None or numbers.Number or array-like or str or function(pandas.DataFrame)
        :param list[float] thresholds: thresholds on prediction
        :param bool errors: if True then use errorbar, else interpolate function
        :param labels_dict: label -- name for class label
            if None then {0: 'bck', '1': 'signal'}
        :type labels_dict: None or OrderedDict(int: str)
        :param int grid_columns: count of columns in grid
        :param float ignored_sideband: (0, 1) percent of plotting data
        :rtype: plotting.GridPlot
        """
        mask, data, class_labels, weight = self._apply_mask(
            mask, self._get_features(features), self.target, self.weight)
        labels_dict = self._check_labels(labels_dict, class_labels)

        plots = []
        for feature in data.columns:
            for name, prediction in self.prediction.items():
                prediction = prediction[mask]
                eff = OrderedDict()
                for label, label_name in labels_dict.items():
                    label_mask = class_labels == label
                    eff[label_name] = utils.get_efficiencies(prediction[label_mask, label],
                                                             data[feature][label_mask].values,
                                                             bins_number=bins,
                                                             sample_weight=weight[label_mask],
                                                             thresholds=thresholds, errors=errors,
                                                             ignored_sideband=ignored_sideband)

                for label_name, eff_data in eff.items():
                    if errors:
                        plot_fig = plotting.ErrorPlot(eff_data)
                    else:
                        plot_fig = plotting.FunctionsPlot(eff_data)
                    plot_fig.xlabel = feature
                    plot_fig.ylabel = 'Efficiency for {}'.format(name)
                    plot_fig.title = '{} flatness'.format(label_name)
                    plot_fig.ylim = (0, 1)
                    plots.append(plot_fig)

        return plotting.GridPlot(grid_columns, *plots)

# %%
def check_arrays(*arrays):
    """
    Left for consistency, version of `sklearn.validation.check_arrays`
    :param list[iterable] arrays: arrays with same length of first dimension.
    """
    assert len(arrays) > 0, 'The number of array must be greater than zero'
    checked_arrays = []
    shapes = []
    for arr in arrays:
        if arr is not None:
            checked_arrays.append(numpy.array(arr))
            shapes.append(checked_arrays[-1].shape[0])
        else:
            checked_arrays.append(None)
    assert numpy.sum(numpy.array(shapes) == shapes[0]) == len(shapes), 'Different shapes of the arrays {}'.format(
        shapes)
    return checked_arrays

# %%
def get_efficiencies(prediction, spectator, sample_weight=None, bins_number=20,
                     thresholds=None, errors=False, ignored_sideband=0.0):
    """
    Construct efficiency function dependent on spectator for each threshold
    Different score functions available: Efficiency, Precision, Recall, F1Score,
    and other things from sklearn.metrics
    :param prediction: list of probabilities
    :param spectator: list of spectator's values
    :param bins_number: int, count of bins for plot
    :param thresholds: list of prediction's threshold
        (default=prediction's cuts for which efficiency will be [0.2, 0.4, 0.5, 0.6, 0.8])
    :return:
        if errors=False
        OrderedDict threshold -> (x_values, y_values)
        if errors=True
        OrderedDict threshold -> (x_values, y_values, y_err, x_err)
        All the parts: x_values, y_values, y_err, x_err are numpy.arrays of the same length.
    """
    prediction, spectator, sample_weight = \
        check_arrays(prediction, spectator, sample_weight)

    spectator_min, spectator_max = weighted_quantile(spectator, [ignored_sideband, (1. - ignored_sideband)])
    mask = (spectator >= spectator_min) & (spectator <= spectator_max)
    spectator = spectator[mask]
    prediction = prediction[mask]
    bins_number = min(bins_number, len(prediction))
    sample_weight = sample_weight if sample_weight is None else numpy.array(sample_weight)[mask]

    if thresholds is None:
        thresholds = [weighted_quantile(prediction, quantiles=1 - eff, sample_weight=sample_weight)
                      for eff in [0.2, 0.4, 0.5, 0.6, 0.8]]

    binner = Binner(spectator, bins_number=bins_number)
    if sample_weight is None:
        sample_weight = numpy.ones(len(prediction))
    bins_data = binner.split_into_bins(spectator, prediction, sample_weight)

    bin_edges = numpy.array([spectator_min] + list(binner.limits) + [spectator_max])
    xerr = numpy.diff(bin_edges) / 2.
    result = OrderedDict()
    for threshold in thresholds:
        x_values = []
        y_values = []
        N_in_bin = []
        for num, (masses, probabilities, weights) in enumerate(bins_data):
            y_values.append(numpy.average(probabilities > threshold, weights=weights))
            N_in_bin.append(numpy.sum(weights))
            if errors:
                x_values.append((bin_edges[num + 1] + bin_edges[num]) / 2.)
            else:
                x_values.append(numpy.mean(masses))

        x_values, y_values, N_in_bin = check_arrays(x_values, y_values, N_in_bin)
        if errors:
            result[threshold] = (x_values, y_values, numpy.sqrt(y_values * (1 - y_values) / N_in_bin), xerr)
        else:
            result[threshold] = (x_values, y_values)
    return result

# %%
def weighted_quantile(array, quantiles, sample_weight=None, array_sorted=False, old_style=False):
    """Computing quantiles of array. Unlike the numpy.percentile, this function supports weights,
    but it is inefficient and performs complete sorting.
    :param array: distribution, array of shape [n_samples]
    :param quantiles: floats from range [0, 1] with quantiles of shape [n_quantiles]
    :param sample_weight: optional weights of samples, array of shape [n_samples]
    :param array_sorted: if True, the sorting step will be skipped
    :param old_style: if True, will correct output to be consistent with numpy.percentile.
    :return: array of shape [n_quantiles]
    Example:
    >>> weighted_quantile([1, 2, 3, 4, 5], [0.5])
    Out: array([ 3.])
    >>> weighted_quantile([1, 2, 3, 4, 5], [0.5], sample_weight=[3, 1, 1, 1, 1])
    Out: array([ 2.])
    """
    array = numpy.array(array)
    quantiles = numpy.array(quantiles)
    sample_weight = check_sample_weight(array, sample_weight)
    assert numpy.all(quantiles >= 0) and numpy.all(quantiles <= 1), 'Percentiles should be in [0, 1]'

    if not array_sorted:
        array, sample_weight = reorder_by_first(array, sample_weight)

    weighted_quantiles = numpy.cumsum(sample_weight) - 0.5 * sample_weight
    if old_style:
        # To be convenient with numpy.percentile
        weighted_quantiles -= weighted_quantiles[0]
        weighted_quantiles /= weighted_quantiles[-1]
    else:
        weighted_quantiles /= numpy.sum(sample_weight)
    return numpy.interp(quantiles, weighted_quantiles, array)

# %%
def check_sample_weight(y_true, sample_weight):
    """Checks the weights, if None, returns array.
    :param y_true: labels (or any array of length [n_samples])
    :param sample_weight: None or array of length [n_samples]
    :return: numpy.array of shape [n_samples]
    """
    if sample_weight is None:
        return numpy.ones(len(y_true), dtype=numpy.float)
    else:
        sample_weight = numpy.array(sample_weight, dtype=numpy.float)
        assert len(y_true) == len(sample_weight), \
            "The length of weights is different: not {0}, but {1}".format(len(y_true), len(sample_weight))
        return sample_weight

# %%
def reorder_by_first(*arrays):
    """
    Applies the same permutation to all passed arrays,
    permutation sorts the first passed array
    """
    arrays = check_arrays(*arrays)
    order = numpy.argsort(arrays[0])
    return [arr[order] for arr in arrays]

class Binner(object):
    def __init__(self, values, bins_number):
        """
        Binner is a class that helps to split the values into several bins.
        Initially an array of values is given, which is then splitted into 'bins_number' equal parts,
        and thus we are computing limits (boundaries of bins).
        """
        percentiles = [i * 100.0 / bins_number for i in range(1, bins_number)]
        self.limits = numpy.percentile(values, percentiles)

    def get_bins(self, values):
        """Given the values of feature, compute the index of bin
        :param values: array of shape [n_samples]
        :return: array of shape [n_samples]
        """
        return numpy.searchsorted(self.limits, values)

    def set_limits(self, limits):
        """Change the thresholds inside bins."""
        self.limits = limits

    @property
    def bins_number(self):
        """:return: number of bins"""
        return len(self.limits) + 1

    def split_into_bins(self, *arrays):
        """
        :param arrays: data to be splitted, the first array corresponds
        :return: sequence of length [n_bins] with values corresponding to each bin.
        """
        values = arrays[0]
        for array in arrays:
            assert len(array) == len(values), "passed arrays have different length"
        bins = self.get_bins(values)
        result = []
        for bin in range(len(self.limits) + 1):
            indices = bins == bin
            result.append([numpy.array(array)[indices] for array in arrays])
        return result
from collections import OrderedDict

# %%
eff = get_efficiencies(y_pred, df_corr_check.mass, thresholds=[0.5]) #, thresholds=[0.2, 0.4, 0.5, 0.6, 0.8])

# %%
eff.keys()
# Out:
# odict_keys([0.5])

# %%
for label_name, eff_data in eff.items():
    pyplot.plot(eff_data[0], eff_data[1], label="global eff  %.1f" % label_name)
pyplot.xlabel('mass')
pyplot.ylabel('Efficiency')
pyplot.legend();

# %%
from utils import check_correlation

# %%
corr_metric = check_correlation(y_pred, df_corr_check['mass'])
print (corr_metric)
# Out:
# 0.00018226797143713961

# %% [markdown]
# ## MC vs Real difference

# %%
df_agreement = pandas.read_csv('reference/check_agreement.csv')

# %%
from sklearn.utils.validation import column_or_1d
def get_ks_metric(df_agree, df_test):
    sig_ind = df_agree[df_agree['signal'] == 1].index
    bck_ind = df_agree[df_agree['signal'] == 0].index

    mc_prob = numpy.array(df_test.loc[sig_ind]['prediction'])
    mc_weight = numpy.array(df_agree.loc[sig_ind]['weight'])
    data_prob = numpy.array(df_test.loc[bck_ind]['prediction'])
    data_weight = numpy.array(df_agree.loc[bck_ind]['weight'])
    val, agreement_metric = check_agreement_ks_sample_weighted(data_prob, mc_prob, data_weight, mc_weight)
    return agreement_metric['ks']

# %%
def check_agreement_ks_sample_weighted (data_prediction, mc_prediction, weights_data, weights_mc):
    data_prediction, weights_data = map(column_or_1d, [data_prediction, weights_data])
    mc_prediction, weights_mc = map(column_or_1d, [mc_prediction, weights_mc])

    assert numpy.all(data_prediction >= 0.) and numpy.all(data_prediction <= 1.), 'error in prediction'
    assert numpy.all(mc_prediction >= 0.) and numpy.all(mc_prediction <= 1.), 'error in prediction'

    weights_data = weights_data / numpy.sum(weights_data)
    weights_mc = weights_mc / numpy.sum(weights_mc)

    data_neg = data_prediction[weights_data < 0]
    weights_neg = -weights_data[weights_data < 0]
    mc_prediction = numpy.concatenate((mc_prediction, data_neg))
    weights_mc = numpy.concatenate((weights_mc, weights_neg))
    data_prediction = data_prediction[weights_data >= 0]
    weights_data = weights_data[weights_data >= 0]

    assert numpy.all(weights_data >= 0) and numpy.all(weights_mc >= 0)
    assert numpy.allclose(weights_data.sum(), weights_mc.sum())

    weights_data /= numpy.sum(weights_data)
    weights_mc /= numpy.sum(weights_mc)

    fpr, tpr, _ = roc_curve_splitted(data_prediction, mc_prediction, weights_data, weights_mc)

    Dnm = numpy.max(numpy.abs(fpr - tpr))
    Dnm_part = numpy.max(numpy.abs(fpr - tpr)[fpr + tpr < 1])

    result = {'ks': Dnm, 'ks_part': Dnm_part}
    return Dnm_part < 0.03, result

# %%
df_agreement.columns
# Out:
# Index(['id', 'LifeTime', 'dira', 'FlightDistance', 'FlightDistanceError', 'IP',
#        'IPSig', 'VertexChi2', 'pt', 'DOCAone', 'DOCAtwo', 'DOCAthree',
#        'IP_p0p2', 'IP_p1p2', 'isolationa', 'isolationb', 'isolationc',
#        'isolationd', 'isolatione', 'isolationf', 'iso', 'CDF1', 'CDF2', 'CDF3',
#        'ISO_SumBDT', 'p0_IsoBDT', 'p1_IsoBDT', 'p2_IsoBDT', 'p0_track_Chi2Dof',
#        'p1_track_Chi2Dof', 'p2_track_Chi2Dof', 'p0_IP', 'p1_IP', 'p2_IP',
#        'p0_IPSig', 'p1_IPSig', 'p2_IPSig', 'p0_pt', 'p1_pt', 'p2_pt', 'p0_p',
#        'p1_p', 'p2_p', 'p0_eta', 'p1_eta', 'p2_eta', 'SPDhits', 'signal',
#        'weight'],
#       dtype='object')

# %%
df_agreement[variables].head()
# Out:
#          IP  p1_IsoBDT  p2_IsoBDT  SPDhits            pt  isolationa  \
# 0  0.058117  -0.089797  -0.098372      512   2251.611816           8
# 1  0.189683  -0.186370  -0.194944      552  10594.470703           5
# 2  0.231709  -0.131069  -0.152291      318   2502.196289           2
# 3  0.011298  -0.177802  -0.434991      290   5097.813965           4
# 4  0.160511  -0.443564  -0.344313       45  20388.097656           0
#
#     DOCAone  p0_IsoBDT          p2_p  VertexChi2         ...           \
# 0  0.082219  -0.019306  15195.594727    7.953543         ...
# 1  0.007983  -0.278330  23134.953125    7.141451         ...
# 2  0.045085  -0.115879  10180.791016    4.778880         ...
# 3  0.055115  -0.208248  24291.875000    5.528002         ...
# 4  0.015587  -0.328938  24241.628906    8.670339         ...
#
#      p1_eta  LifeTime  isolationb          p1_p      IPSig     p0_IP  \
# 0  3.302978  0.001451           6   6380.673828   2.961298  0.483199
# 1  2.834816  0.000679           6  64480.023438  14.413060  0.712242
# 2  3.204923  0.003027           2   3921.181641  11.973175  0.381544
# 3  2.769762  0.000810           4  13221.149414   0.891142  0.564650
# 4  2.262732  0.000706           1  46903.394531  16.367550  0.373736
#
#    isolationd      CDF1  DOCAthree  FlightDistanceError
# 0         2.0  0.732076   0.066887             0.229196
# 1         1.0  0.802508   0.001321             0.517488
# 2         0.0  0.682607   0.005850             0.219291
# 3         0.0  0.533615   0.003864             0.167886
# 4         0.0  0.926410   0.014612             0.284975
#
# [5 rows x 46 columns]

# %%
def compute_ks(data_prediction, mc_prediction, weights_data, weights_mc):
    """
    Compute Kolmogorov-Smirnov (ks) distance between real data predictions cdf and Monte Carlo one.
    :param data_prediction: array-like, real data predictions
    :param mc_prediction: array-like, Monte Carlo data predictions
    :param weights_data: array-like, real data weights
    :param weights_mc: array-like, Monte Carlo weights
    :return: ks value
    """
    assert len(data_prediction) == len(weights_data), 'Data length and weight one must be the same'
    assert len(mc_prediction) == len(weights_mc), 'Data length and weight one must be the same'

    data_prediction, mc_prediction = numpy.array(data_prediction), numpy.array(mc_prediction)
    weights_data, weights_mc = numpy.array(weights_data), numpy.array(weights_mc)

    assert numpy.all(data_prediction >= 0.) and numpy.all(data_prediction <= 1.), 'Data predictions are out of range [0, 1]'
    assert numpy.all(mc_prediction >= 0.) and numpy.all(mc_prediction <= 1.), 'MC predictions are out of range [0, 1]'

    weights_data /= numpy.sum(weights_data)
    weights_mc /= numpy.sum(weights_mc)

    fpr, tpr = __roc_curve_splitted(data_prediction, mc_prediction, weights_data, weights_mc)

    Dnm = numpy.max(numpy.abs(fpr - tpr))
    return Dnm

# %%
from sklearn.metrics import roc_curve
def __roc_curve_splitted(data_zero, data_one, sample_weights_zero, sample_weights_one):
    """
    Compute roc curve
    :param data_zero: 0-labeled data
    :param data_one:  1-labeled data
    :param sample_weights_zero: weights for 0-labeled data
    :param sample_weights_one:  weights for 1-labeled data
    :return: roc curve
    """
    labels = [0] * len(data_zero) + [1] * len(data_one)
    weights = numpy.concatenate([sample_weights_zero, sample_weights_one])
    data_all = numpy.concatenate([data_zero, data_one])
    fpr, tpr, _ = roc_curve(labels, data_all, sample_weight=weights)
    return fpr, tpr

# %%
agreement_probs = clf.predict_proba(df_agreement[variables])[:, 1]

ks = compute_ks(
    agreement_probs[df_agreement['signal'].values == 0],
    agreement_probs[df_agreement['signal'].values == 1],
    df_agreement[df_agreement['signal'] == 0]['weight'].values,
    df_agreement[df_agreement['signal'] == 1]['weight'].values)
print ('KS metric:', ks, "is OK:", ks < 0.09)
# Out:
# KS metric: 0.1903860815716466 is OK: False

# %%
def plot_ks(X_agreement, y_pred):
    sig_ind = X_agreement[X_agreement['signal'] == 1].index
    bck_ind = X_agreement[X_agreement['signal'] == 0].index

    mc_prob = y_pred[sig_ind]
    mc_weight = numpy.array(X_agreement.loc[sig_ind]['weight'])
    data_prob = y_pred[bck_ind]
    data_weight = numpy.array(X_agreement.loc[bck_ind]['weight'])
    inds = data_weight < 0
    mc_weight = numpy.array(list(mc_weight) + list(-data_weight[inds]))
    mc_prob = numpy.array(list(mc_prob) + list(data_prob[inds]))
    data_prob = data_prob[data_weight >= 0]
    data_weight = data_weight[data_weight >= 0]
    hist(data_prob, weights=data_weight, color='r', histtype='step', normed=True, bins=60, label='data')
    hist(mc_prob, weights=mc_weight, color='b', histtype='step', normed=True, bins=60, label='mc')
    xlabel("prediction")
    legend(loc=2)
    show()

# %%
plot_ks(df_agreement, agreement_probs)
# Out:
# C:\Users\Kiko-PC\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### Let's see if adding some noise can improve the agreement

# %%
def add_noise(array, level=0.40, random_seed=34):
    numpy.random.seed(random_seed)
    return level * numpy.random.random(size=array.size) + (1 - level) * array

# %%
agreement_probs_noise = add_noise(clf.predict_proba(df_agreement[variables])[:, 1])

# %%
ks_noise = compute_ks(
    agreement_probs_noise[df_agreement['signal'].values == 0],
    agreement_probs_noise[df_agreement['signal'].values == 1],
    df_agreement[df_agreement['signal'] == 0]['weight'].values,
    df_agreement[df_agreement['signal'] == 1]['weight'].values)
print ('KS metric:', ks_noise, "is OK:", ks_noise < 0.09)
# Out:
# KS metric: 0.08386156396809774 is OK: True

# %%
plot_ks(df_agreement, agreement_probs_noise)
# Out:
# C:\Users\Kiko-PC\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# ### Check ROC with noise

# %%
test.shape
# Out:
# (20266, 51)

# %%
y_pred = add_noise(clf.predict_proba(test[variables])[:, 1])

plot_metrics(test['signal'], y_pred)
test.shape, y_pred.shape
# Out:
# ((20266, 51), (20266,))

# %% [markdown]
# # Train the model using the whole training sample

# %%
# %time clf.fit(train_ada[variables], train_ada['signal'])
# Out:
# Wall time: 1min 59s
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=25,
#             max_features=15, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=50, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=13,
#             splitter='best'),
#           learning_rate=0.01, n_estimators=115, random_state=13)

# %% [markdown]
# Compute prediction and add noise

# %%
y_pred = add_noise(clf.predict_proba(test_ada[variables])[:, 1])

# %% [markdown]
# # Prepare submission file

# %%
def save_submission(y_pred, index, filename='result'):
    sep = ','
    filename = '{}.csv.gz'.format(filename)
    pandas.DataFrame({'id': index, 'prediction': y_pred}).to_csv(
                filename, sep=sep, index=False, compression='gzip')
    print ("Saved file: ", filename, "\nShape:", (y_pred.shape[0], 2))
    return filename

# %%
save_submission(y_pred, test_ada.index, "sample_submission")
# Out:
# Saved file:  sample_submission.csv.gz
# Shape: (855819, 2)
# 'sample_submission.csv.gz'
